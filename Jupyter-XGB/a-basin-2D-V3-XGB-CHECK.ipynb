# %%
# Проверка результативности массивов xgbooster (2017-07-03)

# %%
import sys,os,datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.metrics as skm
from __future__ import print_function

# %%
print(np.__version__);
print(pd.__version__);
# Out:
# 1.12.1
# 0.19.2

# %%
import  cv2 as cv
cv.__version__
# Out:
# '3.2.0'

# %%
import xgboost as xgb

# %%
sys.path.append('../Python')
from helper import formFH, paths_input

# %%
binsData = 96

trLabels,trDirTIF,trDirJPG,teDirTIF,teDirJPG = paths_input()
trWork, teWork = '../Work/Train', '../Work/Test'
print (trWork, teWork)
print (trLabels,trDirTIF,trDirJPG,teDirTIF,teDirJPG)
# Out:
# ../Work/Train ../Work/Test
# ../Data/train_v2.csv ../Data/train-tif-v2 ../Data/train-jpg ../Data/test-tif-v2 ../Data/test-jpg-v2

# %%
binsDataTIF = 96
binsDataJPG = 96

# %%
labels_df = pd.read_csv(trLabels)
labels_df.head()
# Out:
#   image_name                                       tags
# 0    train_0                               haze primary
# 1    train_1            agriculture clear primary water
# 2    train_2                              clear primary
# 3    train_3                              clear primary
# 4    train_4  agriculture clear habitation primary road

# %%
# Build list with unique labels
label_list = []
for tag_str in labels_df.tags.values:
    labels = tag_str.split(' ')
    for label in labels:
        if label not in label_list:
            label_list.append(label)

# %%
# Add features (0 or 1) for every label as dataframe field 
for label in label_list:
    labels_df[label] = labels_df['tags'].apply(lambda x: 1 if label in x.split(' ') else 0)
#labels_df.head()

# %%
weather_labels = ['clear', 'partly_cloudy', 'haze', 'cloudy']
land_labels = ['primary', 'agriculture', 'water', 'cultivation', 'habitation' ]
rare_labels = [l for l in label_list if labels_df[label_list].sum()[l] < 2000]
#rare_labels

# %%
labels = label_list; #weather_labels;
nameList =labels_df[labels_df[labels].sum(axis=1)>0].image_name.tolist(); len(nameList)
labelList=labels_df[labels_df[labels].sum(axis=1)>0][labels].as_matrix();
#labelList[:6,:]
#labels_df.head()

# %%
# Строим основные массивы
dtrain = xgb.DMatrix(trX,label=trY[:,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-00b8fb724e8d> in <module>()
#       1 # Строим основные массивы
# ----> 2 dtrain = xgb.DMatrix(trX,label=trY[:,0])
#
# NameError: name 'trX' is not defined

# %%
# Построение списка bst - моделей
def getListBST (param, trX, trY, nfold=3, early_stop=20) :
    dtrain = xgb.DMatrix(trX,label=trY[:,0])
    results, bstList = [], []
    for i in range(trY.shape[1]) :
        print ('Working: {}'.format(i))
        dtrain.set_label(trY[:,i])
        history = xgb.cv(param, dtrain, metrics=['auc'], 
                         verbose_eval=30, num_boost_round=5000, nfold=nfold, 
                         early_stopping_rounds=early_stop)
        results.append(history)
        rvalidCV, watchlistCV = {}, [(dtrain,'train')]
        bst = xgb.train(param, dtrain, history['test-auc-mean'].argmax()+1, watchlistCV) 
        bstList.append(bst)
    return(bstList)

# Построение решения по dmatrix и bst списку
def buildPredict (dData, bstList) :
    trYP = []
    for bstI in bstList :
        trYP1 = bstI.predict(dData); trYP.append(trYP1)
    trYP = np.array(trYP).T
    #type(trYP),trYP.shape
    return(trYP)

# Построение решения по np.array (DataFrame?) и bst списку
def buildPredictX (Data, bstList) :
    dData = xgb.DMatrix(Data);
    return (buildPredict(dData,bstList))

# %%
# Процедуры для оценки результативности

def getConfusion (tGroundTrue, tPredict) :
    cList = []
    for i in range(tPredict.shape[1]) :
        cList.append(skm.confusion_matrix(tGroundTrue[:,i],tPredict[:,i]))
    return(np.array(cList))

def getRocAUC (tGroundTrue, tPredict) :
    rList = []
    for i in range(tPredict.shape[1]) :
        rList.append(skm.roc_auc_score(tGroundTrue[:,i],tPredict[:,i]))
    return(np.array(rList))

# %%
# Построение пределов прохождения для предсказанного
def getTh (tGround,tPredict, prec=100 ) :
    ixx,iacc = [], []
    for i in range(tGround.shape[1]) :
        max, maxxx = 0.0, 0.0
        for xx in range(0,prec+1) :
            tempYP = getProb01(tPredict[:,i],th=(float(xx)/prec)); #print(tPredict[:,1],tempYP[0])
            temp = skm.accuracy_score(tGround[:,i],tempYP)
            #print(float(xx/10.0),temp)
            if (temp>max) : 
                max = temp; maxxx = float(xx)
                temp = skm.confusion_matrix(tGround[:,i],tempYP);
                minloss = temp[0][1]+temp[1][0]
        ixx.append(maxxx)
        tempYP = getProb01 (tPredict[:,i])
        temp = skm.accuracy_score(tGround[:,i],tempYP)
        minloss05 = skm.confusion_matrix(tGround[:,i],tempYP);
        minloss05 = minloss05[0][1]+minloss05[1][0]
        iacc.append((maxxx,max,temp,minloss,minloss05))
    ixx = [float(xx/prec) for xx in ixx]
    return (ixx,iacc)
#ixx, iacc = getTh(trY,trYPP, prec=100)
#np.array(ixx) , iacc

# %%
# Оценка нескольких наборов
def getProb01 (trYP, th=0.5) :
    trYY = trYP.copy()
    trYY[trYY<th] = 0
    trYY[trYY>0]  = 1
    return (trYY)

def estimateTrain (estimateList, param) :
    res = []
    for jpgtif, bins in estimateList :
        #trX     = np.load('../Work/train-data-XX'+str(bins)+jpgtif+'.npy')
        #trY     = np.load('../Work/train-data-YY'+str(bins)+jpgtif+'.npy')
        trX     = np.load('../Work/t-'+str(10000+bins)+jpgtif+'-XX-train.npy')
        trY     = np.load('../Work/t-'+str(10000+bins)+jpgtif+'-YY-train.npy')
        listBST = getListBST(param, trX, trY)
        trYP    = buildPredictX(trX,listBST)
        trYY    = getProb01(trYP)
        res.append(np.array(getConfusion(trY,trYY)))
    return(res)

# %%
param = {
         'objective':'reg:logistic', 
         #'num_class':17,
         #'eta':0.05, 
         #'max_depth':9, 'subsample':0.8, 'colsample_bytree':0.8, 
         #'metrics':'rmse'
         'eval_metric':['auc','rmse']
        }
param['silent']=True

# %%
xJPG = estimateTrain([('.jpg',256),('.jpg',128),('.jpg',96)],param)
# %time
# Out:
# Working: 0
# [0]	train-auc:0.943547+0.00524291	test-auc:0.929328+0.00505594
# [30]	train-auc:0.988459+0.000516729	test-auc:0.958506+0.00232698
# [60]	train-auc:0.996101+0.000172513	test-auc:0.958487+0.0025079
# [0]	train-auc:0.943299	train-rmse:0.377534
# [1]	train-auc:0.948933	train-rmse:0.300219
# [2]	train-auc:0.958053	train-rmse:0.250566
# [3]	train-auc:0.9606	train-rmse:0.220209
# [4]	train-auc:0.963582	train-rmse:0.201258
# [5]	train-auc:0.966638	train-rmse:0.189529
# [6]	train-auc:0.968566	train-rmse:0.182326
# [7]	train-auc:0.969726	train-rmse:0.177749
# [8]	train-auc:0.970854	train-rmse:0.175135
# [9]	train-auc:0.972179	train-rmse:0.172977
# [10]	train-auc:0.973048	train-rmse:0.171026
# [11]	train-auc:0.974115	train-rmse:0.170041
# [12]	train-auc:0.97567	train-rmse:0.168424
# [13]	train-auc:0.976395	train-rmse:0.167968
# [14]	train-auc:0.977073	train-rmse:0.167384
# [15]	train-auc:0.977724	train-rmse:0.16678
# [16]	train-auc:0.978741	train-rmse:0.165077
# [17]	train-auc:0.979507	train-rmse:0.163399
# [18]	train-auc:0.979794	train-rmse:0.162704
# [19]	train-auc:0.980033	train-rmse:0.162268
# [20]	train-auc:0.980515	train-rmse:0.161824
# [21]	train-auc:0.980979	train-rmse:0.161536
# [22]	train-auc:0.98132	train-rmse:0.16088
# [23]	train-auc:0.982088	train-rmse:0.160152
# [24]	train-auc:0.98225	train-rmse:0.159854
# [25]	train-auc:0.982526	train-rmse:0.1591
# [26]	train-auc:0.982842	train-rmse:0.158173
# [27]	train-auc:0.983317	train-rmse:0.157121
# [28]	train-auc:0.983456	train-rmse:0.156916
# [29]	train-auc:0.984114	train-rmse:0.15533
# [30]	train-auc:0.984319	train-rmse:0.1547
# [31]	train-auc:0.985237	train-rmse:0.152875
# [32]	train-auc:0.985525	train-rmse:0.152277
# [33]	train-auc:0.985857	train-rmse:0.15134
# [34]	train-auc:0.986229	train-rmse:0.150861
# [35]	train-auc:0.986388	train-rmse:0.150348
# [36]	train-auc:0.986636	train-rmse:0.149836
# [37]	train-auc:0.987075	train-rmse:0.148546
# [38]	train-auc:0.987297	train-rmse:0.14806
# [39]	train-auc:0.987538	train-rmse:0.147226
# [40]	train-auc:0.987637	train-rmse:0.146978
# [41]	train-auc:0.987743	train-rmse:0.14663
# [42]	train-auc:0.987995	train-rmse:0.146161
# Working: 1
# [0]	train-auc:0.940238+0.00210897	test-auc:0.928336+0.00596294
# [30]	train-auc:0.993906+0.000857521	test-auc:0.969514+0.00205959
# [60]	train-auc:0.998488+0.000373081	test-auc:0.970472+0.00180199
# [90]	train-auc:0.999756+6.03379e-05	test-auc:0.971293+0.00186189
# [120]	train-auc:0.999979+5.35413e-06	test-auc:0.97153+0.00168516
# [150]	train-auc:1+4.71405e-07	test-auc:0.971651+0.00166113
# [0]	train-auc:0.939677	train-rmse:0.37721
# [1]	train-auc:0.950847	train-rmse:0.299447
# [2]	train-auc:0.955447	train-rmse:0.249118
# [3]	train-auc:0.963444	train-rmse:0.215991
# [4]	train-auc:0.968822	train-rmse:0.194711
# [5]	train-auc:0.972122	train-rmse:0.181045
# [6]	train-auc:0.974055	train-rmse:0.172719
# [7]	train-auc:0.978589	train-rmse:0.166616
# [8]	train-auc:0.980494	train-rmse:0.162463
# [9]	train-auc:0.981333	train-rmse:0.160065
# [10]	train-auc:0.982608	train-rmse:0.158157
# [25]	train-auc:0.957257	train-rmse:0.273748
# [26]	train-auc:0.957532	train-rmse:0.27335
# [27]	train-auc:0.958119	train-rmse:0.272513
# [28]	train-auc:0.958336	train-rmse:0.272002
# [29]	train-auc:0.959155	train-rmse:0.270518
# [30]	train-auc:0.959597	train-rmse:0.270044
# [31]	train-auc:0.959993	train-rmse:0.26958
# [32]	train-auc:0.960418	train-rmse:0.26886
# [33]	train-auc:0.961507	train-rmse:0.266908
# [34]	train-auc:0.962602	train-rmse:0.264908
# [35]	train-auc:0.962848	train-rmse:0.264466
# [36]	train-auc:0.963086	train-rmse:0.263995
# [37]	train-auc:0.963504	train-rmse:0.263497
# [38]	train-auc:0.964017	train-rmse:0.262929
# [39]	train-auc:0.964575	train-rmse:0.261849
# [40]	train-auc:0.964777	train-rmse:0.261465
# [41]	train-auc:0.965004	train-rmse:0.261081
# [42]	train-auc:0.965865	train-rmse:0.259709
# [43]	train-auc:0.96626	train-rmse:0.258885
# [44]	train-auc:0.966491	train-rmse:0.25843
# [45]	train-auc:0.966857	train-rmse:0.257702
# [46]	train-auc:0.96745	train-rmse:0.256757
# [47]	train-auc:0.968238	train-rmse:0.255134
# [48]	train-auc:0.969153	train-rmse:0.253225
# [49]	train-auc:0.9696	train-rmse:0.252242
# [50]	train-auc:0.970063	train-rmse:0.251214
# [51]	train-auc:0.970464	train-rmse:0.250359
# [52]	train-auc:0.970796	train-rmse:0.249679
# [53]	train-auc:0.971281	train-rmse:0.248968
# [54]	train-auc:0.971386	train-rmse:0.248825
# [55]	train-auc:0.971475	train-rmse:0.248711
# [56]	train-auc:0.971921	train-rmse:0.247755
# [57]	train-auc:0.972118	train-rmse:0.247481
# [58]	train-auc:0.972381	train-rmse:0.246893
# [59]	train-auc:0.973338	train-rmse:0.24453
# [60]	train-auc:0.974015	train-rmse:0.242919
# [61]	train-auc:0.974123	train-rmse:0.242667
# [62]	train-auc:0.974288	train-rmse:0.242331
# [63]	train-auc:0.974499	train-rmse:0.241855
# [64]	train-auc:0.974777	train-rmse:0.241203
# [65]	train-auc:0.974925	train-rmse:0.240894
# [66]	train-auc:0.975343	train-rmse:0.240321
# [67]	train-auc:0.975712	train-rmse:0.239604
# [68]	train-auc:0.975774	train-rmse:0.239457
# [69]	train-auc:0.976052	train-rmse:0.238765
# [70]	train-auc:0.976323	train-rmse:0.238131
# [71]	train-auc:0.976709	train-rmse:0.237336
# [72]	train-auc:0.977133	train-rmse:0.236307
# [73]	train-auc:0.977679	train-rmse:0.235099
# [74]	train-auc:0.97803	train-rmse:0.234209
# [75]	train-auc:0.978549	train-rmse:0.232797
# [76]	train-auc:0.97872	train-rmse:0.232353
# Working: 3
# [0]	train-auc:0.955797+0.000508285	test-auc:0.946131+0.00175214
# [30]	train-auc:0.992328+0.000464199	test-auc:0.973001+0.000459361
# [60]	train-auc:0.997398+0.000272757	test-auc:0.974009+0.00056357
# [90]	train-auc:0.999177+8.82836e-05	test-auc:0.974328+0.000418736
# [120]	train-auc:0.999823+2.46892e-05	test-auc:0.974581+0.000296077
# [30]	train-auc:0.996643	train-rmse:0.101484
# [31]	train-auc:0.996755	train-rmse:0.100642
# [32]	train-auc:0.99691	train-rmse:0.099421
# [33]	train-auc:0.997048	train-rmse:0.098595
# [34]	train-auc:0.997114	train-rmse:0.09816
# [35]	train-auc:0.997136	train-rmse:0.097878
# [36]	train-auc:0.997213	train-rmse:0.097177
# [37]	train-auc:0.99725	train-rmse:0.096957
# [38]	train-auc:0.997331	train-rmse:0.096178
# [39]	train-auc:0.997383	train-rmse:0.095845
# [40]	train-auc:0.997472	train-rmse:0.095292
# [41]	train-auc:0.997562	train-rmse:0.094553
# [42]	train-auc:0.997753	train-rmse:0.092791
# [43]	train-auc:0.997855	train-rmse:0.092141
# [44]	train-auc:0.997968	train-rmse:0.090879
# [45]	train-auc:0.998214	train-rmse:0.088486
# [46]	train-auc:0.9984	train-rmse:0.086389
# [47]	train-auc:0.998543	train-rmse:0.085208
# [48]	train-auc:0.998609	train-rmse:0.084742
# [49]	train-auc:0.998647	train-rmse:0.084235
# [50]	train-auc:0.998695	train-rmse:0.083988
# [51]	train-auc:0.998759	train-rmse:0.08306
# [52]	train-auc:0.998804	train-rmse:0.082453
# [53]	train-auc:0.998857	train-rmse:0.081919
# [54]	train-auc:0.998923	train-rmse:0.080914
# [55]	train-auc:0.998952	train-rmse:0.08057
# [56]	train-auc:0.998985	train-rmse:0.080039
# [57]	train-auc:0.999039	train-rmse:0.07922
# [58]	train-auc:0.999092	train-rmse:0.078312
# [59]	train-auc:0.999115	train-rmse:0.078033
# [60]	train-auc:0.999172	train-rmse:0.076872
# [61]	train-auc:0.999194	train-rmse:0.076536
# [62]	train-auc:0.999216	train-rmse:0.076391
# [63]	train-auc:0.999236	train-rmse:0.075942
# [64]	train-auc:0.999305	train-rmse:0.07506
# [65]	train-auc:0.999331	train-rmse:0.07455
# [66]	train-auc:0.999359	train-rmse:0.074061
# [67]	train-auc:0.9994	train-rmse:0.073418
# [68]	train-auc:0.999463	train-rmse:0.071822
# [69]	train-auc:0.999481	train-rmse:0.071324
# [70]	train-auc:0.999498	train-rmse:0.070988
# Working: 10
# [0]	train-auc:0.951034+0.000808383	test-auc:0.936656+0.00242966
# [30]	train-auc:0.995842+0.000113907	test-auc:0.974757+0.00142554
# [60]	train-auc:0.999221+0.000104678	test-auc:0.975863+0.00159981
# [90]	train-auc:0.99989+1.15758e-05	test-auc:0.976313+0.00152617
# [120]	train-auc:0.999998+9.42809e-07	test-auc:0.976962+0.00138709
# [150]	train-auc:1+0	test-auc:0.977332+0.0013658
# [180]	train-auc:1+0	test-auc:0.977753+0.00128767
# [210]	train-auc:1+0	test-auc:0.978038+0.00131034
# [240]	train-auc:1+0	test-auc:0.978225+0.00131276
# [270]	train-auc:1+0	test-auc:0.978502+0.00122907
# [0]	train-auc:0.950126	train-rmse:0.392384
# [1]	train-auc:0.962155	train-rmse:0.32386
# [2]	train-auc:0.968804	train-rmse:0.278263
# [3]	train-auc:0.971446	train-rmse:0.249806
# [4]	train-auc:0.974841	train-rmse:0.22929
# [15]	train-auc:0.998925	train-rmse:0.030391
# [16]	train-auc:0.999267	train-rmse:0.029692
# [17]	train-auc:0.999443	train-rmse:0.028707
# [18]	train-auc:0.999607	train-rmse:0.027848
# [19]	train-auc:0.999753	train-rmse:0.026577
# [20]	train-auc:0.999843	train-rmse:0.025554
# [21]	train-auc:0.999867	train-rmse:0.024735
# [22]	train-auc:0.999929	train-rmse:0.023887
# [23]	train-auc:0.999942	train-rmse:0.022681
# [24]	train-auc:0.999973	train-rmse:0.021744
# [25]	train-auc:0.999991	train-rmse:0.020367
# [26]	train-auc:0.999996	train-rmse:0.019549
# [27]	train-auc:0.999999	train-rmse:0.018168
# [28]	train-auc:1	train-rmse:0.017007
# [29]	train-auc:1	train-rmse:0.016165
# [30]	train-auc:1	train-rmse:0.015142
# [31]	train-auc:1	train-rmse:0.014638
# [32]	train-auc:1	train-rmse:0.013608
# [33]	train-auc:1	train-rmse:0.012785
# [34]	train-auc:1	train-rmse:0.01201
# [35]	train-auc:1	train-rmse:0.011359
# [36]	train-auc:1	train-rmse:0.010613
# [37]	train-auc:1	train-rmse:0.010031
# Working: 12
# [0]	train-auc:0.787878+0.00368181	test-auc:0.746968+0.00488138
# [30]	train-auc:0.994021+0.00114299	test-auc:0.857311+0.00503844
# [60]	train-auc:0.999685+6.86877e-05	test-auc:0.858533+0.00431557
# [0]	train-auc:0.799424	train-rmse:0.366927
# [1]	train-auc:0.837764	train-rmse:0.280558
# [2]	train-auc:0.850993	train-rmse:0.223337
# [3]	train-auc:0.868861	train-rmse:0.185722
# [4]	train-auc:0.876374	train-rmse:0.161764
# [5]	train-auc:0.888715	train-rmse:0.146856
# [6]	train-auc:0.901117	train-rmse:0.137567
# [7]	train-auc:0.907935	train-rmse:0.131757
# [8]	train-auc:0.914843	train-rmse:0.127862
# [9]	train-auc:0.923046	train-rmse:0.125021
# [10]	train-auc:0.928987	train-rmse:0.123378
# [11]	train-auc:0.935021	train-rmse:0.121512
# [12]	train-auc:0.942236	train-rmse:0.120422
# [13]	train-auc:0.947769	train-rmse:0.118799
# [14]	train-auc:0.952912	train-rmse:0.117779
# [15]	train-auc:0.957369	train-rmse:0.116808
# [16]	train-auc:0.958667	train-rmse:0.116211
# [17]	train-auc:0.961431	train-rmse:0.115614
# [18]	train-auc:0.963895	train-rmse:0.115178
# [19]	train-auc:0.966256	train-rmse:0.113987
# [20]	train-auc:0.970491	train-rmse:0.11328
# [21]	train-auc:0.974669	train-rmse:0.111346
# [22]	train-auc:0.976555	train-rmse:0.110665
# [23]	train-auc:0.977841	train-rmse:0.109679
# [24]	train-auc:0.979513	train-rmse:0.108269
# [25]	train-auc:0.981164	train-rmse:0.107293
# [26]	train-auc:0.982263	train-rmse:0.106648
# [27]	train-auc:0.982498	train-rmse:0.106123
# [28]	train-auc:0.98312	train-rmse:0.105852
# [29]	train-auc:0.983613	train-rmse:0.105379
# [30]	train-auc:0.984826	train-rmse:0.104472
# [31]	train-auc:0.985596	train-rmse:0.103652
# [32]	train-auc:0.987709	train-rmse:0.101814
# [42]	train-auc:0.999998	train-rmse:0.014923
# [43]	train-auc:0.999999	train-rmse:0.014435
# [44]	train-auc:0.999999	train-rmse:0.013854
# [45]	train-auc:1	train-rmse:0.013477
# [46]	train-auc:1	train-rmse:0.012673
# [47]	train-auc:1	train-rmse:0.012071
# [48]	train-auc:1	train-rmse:0.011571
# [49]	train-auc:1	train-rmse:0.011144
# [50]	train-auc:1	train-rmse:0.011049
# [51]	train-auc:1	train-rmse:0.010442
# [52]	train-auc:1	train-rmse:0.009925
# [53]	train-auc:1	train-rmse:0.009353
# [54]	train-auc:1	train-rmse:0.008936
# [55]	train-auc:1	train-rmse:0.008691
# [56]	train-auc:1	train-rmse:0.00822
# [57]	train-auc:1	train-rmse:0.007989
# [58]	train-auc:1	train-rmse:0.007687
# [59]	train-auc:1	train-rmse:0.007357
# Working: 14
# [0]	train-auc:0.634479+0.119955	test-auc:0.590609+0.0934857
# [30]	train-auc:0.997525+0.000424297	test-auc:0.880673+0.0118199
# [0]	train-auc:0.802142	train-rmse:0.359535
# [1]	train-auc:0.825203	train-rmse:0.26665
# [2]	train-auc:0.852242	train-rmse:0.203113
# [3]	train-auc:0.867697	train-rmse:0.159573
# [4]	train-auc:0.874296	train-rmse:0.130365
# [5]	train-auc:0.882841	train-rmse:0.111217
# [6]	train-auc:0.89508	train-rmse:0.099197
# [7]	train-auc:0.902548	train-rmse:0.091813
# [8]	train-auc:0.917604	train-rmse:0.087376
# [9]	train-auc:0.92413	train-rmse:0.084644
# [10]	train-auc:0.932169	train-rmse:0.08282
# [11]	train-auc:0.942063	train-rmse:0.081571
# [12]	train-auc:0.948079	train-rmse:0.080465
# [13]	train-auc:0.955131	train-rmse:0.07979
# [14]	train-auc:0.96119	train-rmse:0.07906
# [15]	train-auc:0.966243	train-rmse:0.078801
# [16]	train-auc:0.969369	train-rmse:0.078374
# [17]	train-auc:0.970818	train-rmse:0.077986
# [18]	train-auc:0.973787	train-rmse:0.077331
# [19]	train-auc:0.97694	train-rmse:0.07691
# [20]	train-auc:0.978061	train-rmse:0.076553
# [21]	train-auc:0.978696	train-rmse:0.07639
# [22]	train-auc:0.981951	train-rmse:0.075946
# [23]	train-auc:0.984031	train-rmse:0.075329
# [24]	train-auc:0.985035	train-rmse:0.074513
# [25]	train-auc:0.987922	train-rmse:0.072759
# [26]	train-auc:0.989022	train-rmse:0.072072
# [27]	train-auc:0.990478	train-rmse:0.070859
# [28]	train-auc:0.991502	train-rmse:0.070138
# [29]	train-auc:0.992082	train-rmse:0.06994
# [30]	train-auc:0.99245	train-rmse:0.069679
# [31]	train-auc:0.992639	train-rmse:0.06939
# [32]	train-auc:0.994123	train-rmse:0.067747
# [33]	train-auc:0.994382	train-rmse:0.067225
# [34]	train-auc:0.994452	train-rmse:0.066948
# [35]	train-auc:0.995006	train-rmse:0.066088
# [36]	train-auc:0.995269	train-rmse:0.065618
# [37]	train-auc:0.996207	train-rmse:0.064008
# Working: 15
# [0]	train-auc:0.502138+0.00302406	test-auc:0.499763+0.000334697
# [30]	train-auc:0.996825+0.000373279	test-auc:0.872872+0.0171382
# [0]	train-auc:0.782155	train-rmse:0.359892
# [1]	train-auc:0.815757	train-rmse:0.267278
# [2]	train-auc:0.866318	train-rmse:0.204053
# [3]	train-auc:0.884613	train-rmse:0.160902
# [4]	train-auc:0.903591	train-rmse:0.132208
# [5]	train-auc:0.910874	train-rmse:0.113752
# [6]	train-auc:0.915011	train-rmse:0.102131
# [7]	train-auc:0.924386	train-rmse:0.095112
# [8]	train-auc:0.929101	train-rmse:0.090936
# [9]	train-auc:0.937427	train-rmse:0.088156
# [10]	train-auc:0.946945	train-rmse:0.086513
# [11]	train-auc:0.953624	train-rmse:0.085525
# [12]	train-auc:0.957581	train-rmse:0.084806
# [13]	train-auc:0.961963	train-rmse:0.084373
# [14]	train-auc:0.966401	train-rmse:0.08338
# [15]	train-auc:0.969993	train-rmse:0.08251
# [16]	train-auc:0.97692	train-rmse:0.082113
# [17]	train-auc:0.978859	train-rmse:0.080994
# [18]	train-auc:0.980986	train-rmse:0.08076
# [19]	train-auc:0.982415	train-rmse:0.079662
# [20]	train-auc:0.984249	train-rmse:0.078696
# [21]	train-auc:0.98556	train-rmse:0.078075
# [22]	train-auc:0.986722	train-rmse:0.077686
# [23]	train-auc:0.987568	train-rmse:0.077043
# [24]	train-auc:0.988743	train-rmse:0.076113
# [25]	train-auc:0.990239	train-rmse:0.074693
# [26]	train-auc:0.990853	train-rmse:0.074114
# [27]	train-auc:0.991643	train-rmse:0.073559
# [28]	train-auc:0.992572	train-rmse:0.071947
# [29]	train-auc:0.992942	train-rmse:0.071712
# [30]	train-auc:0.993324	train-rmse:0.071348
# [31]	train-auc:0.994532	train-rmse:0.069724
# [32]	train-auc:0.995251	train-rmse:0.068489
# [33]	train-auc:0.995875	train-rmse:0.066833
# [34]	train-auc:0.996252	train-rmse:0.065449
# [35]	train-auc:0.996545	train-rmse:0.064954
# [36]	train-auc:0.996751	train-rmse:0.064743
# [37]	train-auc:0.996858	train-rmse:0.064162
# [38]	train-auc:0.996952	train-rmse:0.063844
# [39]	train-auc:0.997084	train-rmse:0.063468
# Working: 16
# [0]	train-auc:0.5+0	test-auc:0.5+0
# [30]	train-auc:0.999607+0.000498524	test-auc:0.810286+0.0311747
# [60]	train-auc:1+0	test-auc:0.806529+0.0318952
# [0]	train-auc:0.5	train-rmse:0.356009
# [1]	train-auc:0.5	train-rmse:0.259781
# [2]	train-auc:0.5	train-rmse:0.192554
# [3]	train-auc:0.5	train-rmse:0.145101
# [4]	train-auc:0.687558	train-rmse:0.111534
# [5]	train-auc:0.708264	train-rmse:0.088079
# [6]	train-auc:0.713204	train-rmse:0.071969
# [7]	train-auc:0.736668	train-rmse:0.06129
# [8]	train-auc:0.86074	train-rmse:0.054378
# [9]	train-auc:0.882476	train-rmse:0.049696
# [10]	train-auc:0.93267	train-rmse:0.046786
# [11]	train-auc:0.96324	train-rmse:0.044931
# [12]	train-auc:0.9717	train-rmse:0.044019
# [13]	train-auc:0.975722	train-rmse:0.042131
# [14]	train-auc:0.988697	train-rmse:0.041323
# [15]	train-auc:0.989125	train-rmse:0.040408
# [16]	train-auc:0.990002	train-rmse:0.039548
# [17]	train-auc:0.991876	train-rmse:0.038837
# [18]	train-auc:0.992624	train-rmse:0.038836
# [19]	train-auc:0.995835	train-rmse:0.037937
# [20]	train-auc:0.995381	train-rmse:0.037448
# [21]	train-auc:0.996697	train-rmse:0.036771
# [22]	train-auc:0.997235	train-rmse:0.036091
# [23]	train-auc:0.997548	train-rmse:0.035055
# [24]	train-auc:0.997736	train-rmse:0.034496
# [25]	train-auc:0.998258	train-rmse:0.033724
# [26]	train-auc:0.998338	train-rmse:0.033321
# [27]	train-auc:0.998462	train-rmse:0.032648
# [28]	train-auc:0.998972	train-rmse:0.03159
# [29]	train-auc:0.999364	train-rmse:0.030189
# [30]	train-auc:0.999454	train-rmse:0.029565
# [31]	train-auc:0.99953	train-rmse:0.028911
# [32]	train-auc:0.99978	train-rmse:0.02784
# [33]	train-auc:0.999858	train-rmse:0.026724
# [34]	train-auc:0.999868	train-rmse:0.026097
# [35]	train-auc:0.999912	train-rmse:0.024747
# [36]	train-auc:0.999954	train-rmse:0.024137
# [37]	train-auc:0.999978	train-rmse:0.022488
# [38]	train-auc:0.999985	train-rmse:0.02166
# [39]	train-auc:0.999995	train-rmse:0.02085
# [40]	train-auc:0.999997	train-rmse:0.020336
# [41]	train-auc:0.999998	train-rmse:0.01957
# [42]	train-auc:1	train-rmse:0.019047
# [43]	train-auc:1	train-rmse:0.018531
# [44]	train-auc:1	train-rmse:0.018001
# [45]	train-auc:1	train-rmse:0.016891
# [46]	train-auc:1	train-rmse:0.016415
# [47]	train-auc:1	train-rmse:0.015406
# [48]	train-auc:1	train-rmse:0.014788
# [49]	train-auc:1	train-rmse:0.014272
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 5.96 µs

# %%
#xJPG
for cms in xJPG :
    cm = cms[:,0,1]+cms[:,1,0]
    print (cm.sum(),cms[:,0,1]+cms[:,1,0])
# %time
# Out:
# 14885 [1149   38 2821  338 3083  431 2639 3334    9  205    0    0  524    0  212
#    92   10]
# 14488 [ 946   95 3482  532  395 1479 3180 3275   81   42    0    0  463    0  278
#   211   29]
# 17857 [1087  153 3360  776 2192 1495 3837 3323  194    0  470    2  493    0  229
#   243    3]
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 5.01 µs

# %%
#xJPG
for cms in xJPG :
    cm = cms[:,0,1]+cms[:,1,0]
    print (cm.sum(),cms[:,0,1]+cms[:,1,0])
# %time
# Out:
# 19743 [1224  629 3295  576 4277 1799 2939 3338  206   13  408    0  433   13  234
#   324   35]
# 18538 [1248   90 3625 1106 2927 1603 3518 2655  194   38  233    0  658    0  264
#   303   76]
# 15592 [1338  470 2304  551 2569 1136 3111 2691  168  143   18   24  532    0  269
#   227   41]
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 5.96 µs

# %%
#xTIF = estimateTrain([('.tif',32),('.tif',64),('.tif',96)],param)
# %time
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 14.1 µs

# %%
for cms in xTIF :
    cm = cms[:,0,1]+cms[:,1,0]
    print (cm.sum(),cms[:,0,1]+cms[:,1,0])
# %time
# Out:
# 23842 [1438 1001 3107 1913 3395 1967 4088 3460  188  413 1761   17  492    6  197
#   301   98]
# 21119 [1015  864 3257  846 3520 1771 3654 3382  149  369  994   54  654    9  198
#   304   79]
# 17984 [ 874  783 2743  732 3002 1824 3533 3074   57   99  146    0  658   24  303
#    53   79]
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 4.05 µs

# %%
wr = [labels.index(i) for i in weather_labels]; wr
print(labels)
trYPP[trYPP[:,wr].argmax(axis=1)<>trY[:,wr].argmax(axis=1)].shape, wr, (40497.0-498)/40497.0, (40497.0-898)/40497.0
# Out:
# ['haze', 'primary', 'agriculture', 'clear', 'water', 'habitation', 'road', 'cultivation', 'slash_burn', 'cloudy', 'partly_cloudy', 'conventional_mine', 'bare_ground', 'artisinal_mine', 'blooming', 'selective_logging', 'blow_down']
# ((549, 17), [3, 10, 0, 9], 0.9877027927994666, 0.9778255179396005)

# %%
# Построение значимости полей для разных признаков (importance)
bstga   = np.zeros((trX.shape[1],trY.shape[1]))
for i in range(len(bstList)) :
    bstgfs = bstList[i].get_fscore()
    bstgfs = [(int(n.split('f')[1]),bstgfs[n]) for n in bstgfs.keys()]
    bstga1 = np.array(bstgfs)
    bstga[bstga1[:,0],i] = bstga1[:,1]


if False :
    #bstgfs.sort(key=lambda x: -x[1])
    #bstgfs[:20]
    plt.hist([nn for n,nn in bstgfs],bins=11); plt.show()
    bst_gfs_main = [(n,nn) for n,nn in bstgfs if nn>=20]
    bst_gfs_main.sort(key=lambda x: x[0])
    bst_gfs_main
    bstga[:,6]

# %%
xx = [0]+range(2,8)+[12] # плохие 600-4000
plt.plot(bstga[:,xx]); 
#plt.legenda([labels[x] for x in xx])
plt.show();
[labels[x] for x in xx]
# Out:
# ['haze',
#  'agriculture',
#  'clear',
#  'water',
#  'habitation',
#  'road',
#  'cultivation',
#  'bare_ground']

# %%
xx = [8,10,14,15] # среднии 100-400
plt.plot(bstga[:,xx]); 
#plt.legenda([labels[x] for x in xx])
plt.show();
[labels[x] for x in xx]
# Out:
# ['slash_burn', 'partly_cloudy', 'blooming', 'selective_logging']

# %%
xx = [1,9,10,11,13,15,16] # отличные 0-100
plt.plot(bstga[:,xx]); plt.show();
[labels[x] for x in xx]
# Out:
# ['primary',
#  'cloudy',
#  'partly_cloudy',
#  'conventional_mine',
#  'artisinal_mine',
#  'selective_logging',
#  'blow_down']

# %%
# Посчитать уровень прохождения для каждого признака
ixx, iacc = getTh(trY,trYPP)
np.array(ixx), iacc
# Out:
# (array([ 0.39,  0.42,  0.46,  0.54,  0.4 ,  0.35,  0.44,  0.35,  0.19,
#          0.25,  0.08,  0.08,  0.24,  0.1 ,  0.19,  0.22,  0.14]),
#  [(39.0, 0.97872971170236422, 0.97769213666345511, 861, 903),
#   (42.0, 0.99997529583240696, 0.99997529583240696, 1, 1),
#   (46.0, 0.94021591442476349, 0.93851132686084138, 2420, 2489),
#   (54.0, 0.97490056572543793, 0.974282961535611, 1016, 1041),
#   (40.0, 0.93611502260431334, 0.93260703080609697, 2586, 2728),
#   (35.0, 0.98085427011536841, 0.97643222411620845, 775, 954),
#   (44.0, 0.9399194644136466, 0.93653499345339564, 2432, 2569),
#   (35.0, 0.9494058647693866, 0.93962301440252971, 2048, 2444),
#   (19.0, 0.99945650831295241, 0.99752958324069274, 22, 100),
#   (25.0, 1.0, 1.0, 0, 0),
#   (8.0, 1.0, 1.0, 0, 0),
#   (8.0, 1.0, 1.0, 0, 0),
#   (24.0, 0.99041478297388774, 0.98715383285160208, 388, 520),
#   (10.0, 1.0, 1.0, 0, 0),
#   (19.0, 0.99622026235825989, 0.99407099977766245, 153, 240),
#   (22.0, 0.999332987474987, 0.99770251241384422, 27, 93),
#   (14.0, 0.99965414165369693, 0.99891301662590481, 14, 44)])

# %%
# Forming output dataset for predicting --> trOX, trOY
#del(trX)
#del(trY)

# %%
# Данные для объединения от jpg
##trOX_JPG1 = np.load('../Work/test-data-XX'+str(binsDataJPG)+'.jpg'+'.npy')
##trOX_JPG2 = np.load('../Work/test-data-XX'+str(binsDataJPG2)+'.jpg'+'.npy')
trOX_JPG  = np.load('../Work/test-data-XX'+str(binsDataJPG)+'.jpg'+'.npy')
trOX_TIF  = np.load('../Work/test-data-XX'+str(binsDataTIF)+'.tif'+'.npy')
trOY_TIF  = np.load('../Work/test-data-YY'+str(binsDataTIF)+'.tif'+'.npy')
#trOY_JPG1 = np.load('../Work/test-data-YY'+str(binsDataJPG)+'.jpg'+'.npy')
#trOY_JPG2 = np.load('../Work/test-data-YY'+str(binsDataJPG2)+'.jpg'+'.npy')
trOY_JPG = np.load('../Work/test-data-YY'+str(binsDataJPG)+'.jpg'+'.npy')

# %%
#trOX_TIF.shape, trOX_JPG.shape, trOX_JPG2.shape , 578+255+192
trOX_TIF.shape, trOX_JPG.shape , 578+255+192
# Out:
# ((61191, 578), (61191, 255), 1025)

# %%
# Обрезка видимой части и использование только n, nvi, dwi
##trOX_TIF = trOX_TIF[:,288:]
##trOX_TIF.shape

# %%
# Аккуратно объединяем через индексы = имена файлов
dfOX_TIF  = pd.DataFrame(trOX_TIF,index=trOY_TIF)
##dfOX_JPG1 = pd.DataFrame(trOX_JPG,index=trOY_JPG1)
##dfOX_JPG2 = pd.DataFrame(trOX_JPG2,index=trOY_JPG2)
##dfOX_JPG  = dfOX_JPG1.join(dfOX_JPG2,lsuffix='_l',rsuffix='_r')

dfOX_JPG = pd.DataFrame(trOX_JPG,index=trOY_JPG)
dfOX     = dfOX_JPG.join(dfOX_TIF,lsuffix='_l',rsuffix='_r')

dfOX.shape #, dfOX.columns,dfOX.head()
# Out:
# (61191, 833)

# %%
trOX = dfOX.values
trOY = dfOX.index.values
trOX.shape,trOY.shape,trOY[0:10]
# Out:
# ((61191, 833),
#  (61191,),
#  array(['test_10002', 'test_10003', 'test_10004', 'test_10005',
#         'test_10006', 'test_10007', 'test_10008', 'test_10009', 'test_1001',
#         'test_10010'], dtype=object))

# %%
# Формирование результата
dtest  = xgb.DMatrix(trOX)

# %%
trP = []
for bstI in bstList :
    trP1 = bstI.predict(dtest);
    trP.append(trP1)
trP = np.array(trP).T
type(trP),trP.shape
# Out:
# (numpy.ndarray, (61191, 17))

# %%
#np.save('../Work/test-data-RR'+str(binsData)+ttExt+'.npy',trP)

# %%
#trP = np.load('../Work/test-data-RR'+str(binsData)+ttExt+'.npy')
#trP.shape

# %%
wr = [labels.index(i) for i in weather_labels];
trM=np.array(ixx) #np.array([0.5]*17);
#### Коэффициенты работают +0.01 к счету trM=np.array([0.5]*17);
trM[np.array(wr)] = 2.0
print(wr,'\n',labels,'\n',trM.tolist())
# Out:
# [3, 10, 0, 9]
#  ['haze', 'primary', 'agriculture', 'clear', 'water', 'habitation', 'road', 'cultivation', 'slash_burn', 'cloudy', 'partly_cloudy', 'conventional_mine', 'bare_ground', 'artisinal_mine', 'blooming', 'selective_logging', 'blow_down']
#  [2.0, 0.42, 0.46, 2.0, 0.4, 0.35, 0.44, 0.35, 0.19, 2.0, 2.0, 0.08, 0.24, 0.1, 0.19, 0.22, 0.14]

# %%
#trP = model.predict(trX, batch_size=512); trP=K.get_value(trP)
res = []

for i in range(trP.shape[0]) :
    trA1 = [weather_labels[trP[i,wr].argmax()]]
    trA2 = [labels[ii] for ii in range(len(labels)) if (trP[i,ii]>trM[ii])]
    trPP = trA1 + trA2;
    pp   = ' '.join(trPP)
    ##if (pp=="") : print(trY[i])
    res.append([trOY[i],pp])

res.sort(cmp=lambda x,y: cmp(int(x[0].partition('_')[2]),int(y[0].partition('_')[2])) if (x[0].partition('_')[0]==y[0].partition('_')[0]) else cmp(y[0].partition('_')[0],x[0].partition('_')[0]))
#print(res[4:8],'\n',res[-4:])
print(res[0],'\n',res[-1],'\n',trM,trP[0])
# Out:
# ['test_0', 'clear primary']
#  ['file_20521', 'clear primary']
#  [ 2.    0.42  0.46  2.    0.4   0.35  0.44  0.35  0.19  2.    2.    0.08
#   0.24  0.1   0.19  0.22  0.14] [  4.30692956e-02   3.47555101e-01   6.04333766e-02   2.93665826e-01
#    1.17301032e-01   2.01818300e-03   3.60038574e-03   1.09107210e-03
#    2.75305702e-05   8.66805375e-01   3.23356013e-04   2.19742469e-05
#    2.54213880e-03   2.35209177e-06   1.78975912e-04   2.23689625e-04
#    1.82826421e-04]

# %%
print(labels)
print(trM.tolist())
#np.round(trP[4:11,:])
# Out:
# ['haze', 'primary', 'agriculture', 'clear', 'water', 'habitation', 'road', 'cultivation', 'slash_burn', 'cloudy', 'partly_cloudy', 'conventional_mine', 'bare_ground', 'artisinal_mine', 'blooming', 'selective_logging', 'blow_down']
# [2.0, 0.42, 0.46, 2.0, 0.4, 0.35, 0.44, 0.35, 0.19, 2.0, 2.0, 0.08, 0.24, 0.1, 0.19, 0.22, 0.14]

# %%
rrr=pd.DataFrame(res,columns=['image_name','tags']); rrr.head(); 
suffixDT = (datetime.datetime.now()).strftime('%Y-%m-%d-%H-%M-%S'); print(suffixDT)
rrr.to_csv('../Result/vss'+suffixDT+'.csv',index=False);
# Out:
# 2017-07-03-19-48-53
